# %%
import numpy as np
from data import get_test_set

# %%
# %%timeit
dataset = get_test_set()
x = next(iter(dataset))
print(len(x))
print(x[0].shape)
print(x[1].shape)
# Out:
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# ...

# %%
# %%timeit
dataset = get_test_set()
for x in test_data_loader:
    print(len(x))
    print(x[0].shape)
    print(x[1].shape)
# Out:
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# torch.Size([3, 1568, 512])
# 2
# torch.Size([3, 49, 16])
# ...

# %%
from torch.utils.data import DataLoader

# %%
# %%timeit
dataset = get_test_set()
test_data_loader = DataLoader(dataset=dataset, num_workers=4, batch_size=128, shuffle=False)
x = next(iter(test_data_loader))
print(len(x))
print(x[0].shape)
print(x[1].shape)
# Out:
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 35.4 s ± 6.77 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
dataset = get_test_set()
test_data_loader = DataLoader(dataset=dataset, num_workers=4, batch_size=128, shuffle=False)
for x in test_data_loader:
    print(len(x))
    print(x[0].shape)
    print(x[1].shape)
# Out:
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([104, 3, 49, 16])
# torch.Size([104, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# ...

# %%
# %%timeit
dataset = get_test_set()
test_data_loader = DataLoader(dataset=dataset, num_workers=2, batch_size=128, shuffle=False)
for i, x in enumerate(test_data_loader):
    print(i, len(x))
    print(x[0].shape)
    print(x[1].shape)
# Out:
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([104, 3, 49, 16])
# torch.Size([104, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# torch.Size([128, 3, 49, 16])
# torch.Size([128, 3, 1568, 512])
# 2
# ...

# %%
# %%timeit
dataset = get_test_set()
test_data_loader = DataLoader(dataset=dataset, num_workers=4, batch_size=64, shuffle=False)
for i, x in enumerate(test_data_loader):
    print(i, len(x))
    print(x[0].shape)
    print(x[1].shape)
# Out:
# 0 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 1 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 2 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 3 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 4 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 5 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 6 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 7 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 8 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 9 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 10 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 11 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 12 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 13 2
# torch.Size([64, 3, 49, 16])
# torch.Size([64, 3, 1568, 512])
# 14 2
# ...

# %%
# %%timeit
dataset = get_test_set()
test_data_loader = DataLoader(dataset=dataset, num_workers=4, batch_size=32, shuffle=False)
for i, x in enumerate(test_data_loader):
    print(i, len(x))
    print(x[0].shape)
    print(x[1].shape)
# Out:
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# torch.Size([32, 3, 1568, 512])
# 2
# torch.Size([32, 3, 49, 16])
# ...

# %%
# %%timeit
dataset = get_test_set()
test_data_loader = DataLoader(dataset=dataset, num_workers=4, batch_size=16, shuffle=False)
for i, x in enumerate(test_data_loader):
    print(i, len(x))
    print(x[0].shape)
    print(x[1].shape)
# Out:
# 0 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 1 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 2 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 3 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 4 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 5 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 6 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 7 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 8 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 9 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 10 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 11 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 12 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 13 2
# torch.Size([16, 3, 49, 16])
# torch.Size([16, 3, 1568, 512])
# 14 2
# ...
